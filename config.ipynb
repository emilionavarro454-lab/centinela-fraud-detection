# %% [markdown]
# # Configuración compartida — CENTINELA
#
# Constantes, rutas, colores, variables de análisis y tipos de datos compartidos por los notebooks del proyecto.

# %%
from pathlib import Path

# Configuración general
SEED = 42
NOMBRE_ZIP = 'Base.csv.zip'
NOMBRE_CSV = 'Base.csv'
DIAS_VALIDACION = 30
DIAS_TEST = 61

# Colores y paletas
COLOR_LEGITIMO = '#2A9D8F'
COLOR_FRAUDE = '#D62828'
COLOR_AVISO = '#E9C46A'

PALETA_FRAUDE = {
    0: COLOR_LEGITIMO,
    1: COLOR_FRAUDE,
}

# Rutas
RUTA_PROYECTO = Path('/content/drive/MyDrive/TFM_Fraude')
RUTA_ZIPS = RUTA_PROYECTO / 'data'
RUTA_LOCAL = Path('/content/data')
RUTA_SALIDAS = RUTA_PROYECTO / 'outputs'
RUTA_FIGURAS = RUTA_SALIDAS / 'figuras'
RUTA_MODELOS = RUTA_SALIDAS / 'modelos'
RUTA_REPORTES = RUTA_SALIDAS / 'reportes'
RUTA_DASH = RUTA_SALIDAS / 'dashboard'
RUTA_PBI = RUTA_SALIDAS / 'powerbi'

# Variables de análisis
VARS_NUM = [
    'credit_risk_score',
    'name_email_similarity',
    'customer_age',
    'proposed_credit_limit',
    'date_of_birth_distinct_emails_4w',
    'current_address_months_count',
]

# Tipos de datos del dataset
TIPOS_COLUMNAS = {
    # Objetivo y calendario
    'fraud_bool': 'int8',
    'month': 'int8',

    # Banderas binarias
    'email_is_free': 'int8',
    'phone_home_valid': 'int8',
    'phone_mobile_valid': 'int8',
    'has_other_cards': 'int8',
    'foreign_request': 'int8',
    'keep_alive_session': 'int8',
    'device_fraud_count': 'int8',

    # Enteros pequeños
    'customer_age': 'int8',
    'device_distinct_emails_8w': 'int8',
    'date_of_birth_distinct_emails_4w': 'int8',

    # Contadores
    'prev_address_months_count': 'int16',
    'current_address_months_count': 'int16',
    'bank_months_count': 'int16',
    'zip_count_4w': 'int16',
    'bank_branch_count_8w': 'int16',
    'credit_risk_score': 'int16',

    # Decimales
    'income': 'float32',
    'name_email_similarity': 'float32',
    'days_since_request': 'float32',
    'intended_balcon_amount': 'float32',
    'velocity_6h': 'float32',
    'velocity_24h': 'float32',
    'velocity_4w': 'float32',
    'proposed_credit_limit': 'float32',
    'session_length_in_minutes': 'float32',

    # Categóricas
    'payment_type': 'category',
    'employment_status': 'category',
    'housing_status': 'category',
    'source': 'category',
    'device_os': 'category',
}

# Variables categóricas
VARS_CAT = [
    'payment_type',
    'employment_status',
    'housing_status',
    'source',
    'device_os',
]

# Ratios
RATIOS = [
    'ratio_velocidad_6h_24h',
    'ratio_velocidad_24h_4w',
    'presion_zip'
]

VARS_TEST_NUM = [
    'credit_risk_score', 'name_email_similarity', 'customer_age', 'income',
    'proposed_credit_limit', 'current_address_months_count', 'velocity_4w',
    'zip_count_4w', 'date_of_birth_distinct_emails_4w',
    'session_length_in_minutes'
]

VARS_TEST_CAT = VARS_CAT + [
    'email_is_free', 'has_other_cards', 'foreign_request',
    'keep_alive_session', 'phone_home_valid'
]

CATEG = VARS_CAT

NOMBRES_NEGOCIO = {
    'credit_risk_score': 'puntuación de riesgo crediticio',
    'name_email_similarity': 'similitud entre nombre y correo',
    'proposed_credit_limit': 'límite de crédito solicitado',
    'current_address_months_count': 'meses en el domicilio actual',
    'prev_address_months_count_ausente': 'sin dato de domicilio anterior',
    'bank_months_count_ausente': 'sin historial en el banco',
    'customer_age': 'edad (décadas)',
    'income': 'nivel de ingresos (decil)',
    'keep_alive_session': 'sesión mantenida activa',
    'has_other_cards': 'posee otras tarjetas de la entidad',
    'date_of_birth_distinct_emails_4w': 'correos distintos con su fecha de nacimiento (4 sem)',
    'device_distinct_emails_8w': 'correos distintos desde su dispositivo (8 sem)',
    'phone_home_valid': 'teléfono fijo verificado',
    'n_faltantes': 'campos sin completar en la solicitud',
    'housing_status_BA': 'situación de vivienda tipo BA',
    'employment_status_CC': 'situación laboral tipo CC',
    'device_os_windows': 'dispositivo con sistema windows',
}

LIBS = ['numpy', 'pandas', 'scikit-learn', 'lightgbm', 'xgboost',
        'shap', 'optuna', 'joblib', 'matplotlib', 'seaborn']

NOMBRES_CORTOS = {
    'velocity_4w': 'velocidad 4 sem',
    'velocity_24h': 'velocidad 24 h',
    'velocity_6h': 'velocidad 6 h',
    'zip_count_4w': 'código postal 4 sem',
    'date_of_birth_distinct_emails_4w': 'emails por fecha nac.',
    'credit_risk_score': 'score de riesgo',
    'bank_branch_count_8w': 'sucursal 8 sem',
    'current_address_months_count': 'meses en domicilio',
    'session_length_in_minutes': 'duración de sesión',
    'income': 'ingresos',
    'name_email_similarity': 'similitud nombre-correo',
    'proposed_credit_limit': 'límite solicitado',
    'customer_age': 'edad',
}
